# %%
import numpy as np
import random
import os

def clearScreen():
    if os.name == 'posix':
	#For UNIX Systems
        _ = os.system('clear')
    else:
	#For Windows
        _ = os.system('cls')

def playGame():
    global board
    global array
    board = np.full((3,3),2,dtype= int)   #to print a board
    array = np.arange(1,10).reshape((3,3)) #to indexing the inputs 
    

    #to select a starting turn
    global user_num 
    global com_num 
    #0 act as "O"
    #1 act as "X"
    Turn = random.randint(0,2)
    if Turn == 0:
        user_num = 0
        com_num = 1
        print("Its computer turns. your turn will go with O")
        compTurn()
    
    elif Turn == 1:
        user_num = 1
        com_num = 0
        print("Its your turn will go with X")
        userTurn()

#printing a board

def displayBoard():
    board_list = []
    Values = board.flatten()
    Values

    for i in range(0,9):
        if Values[i]== 0:
            board_list.append("O")
        elif Values[i]== 1:
            board_list.append("X")
        elif Values[i]== 2:
            board_list.append(" ")
        else:
            raise Exception("board display error")
            
    print('''
          
         {} | {} | {}
        ---+---+---
         {} | {} | {}
        ---+---+---
         {} | {} | {}
          
          '''.format(*board_list)) #???

def checkSlot():
    open_slot = []    #to save blank slots
    slot = (board==2)   #Returns True when array values contain 2(blank spaces)
    slot_list = slot.flatten()
    
    
    for i in range(0, len(slot_list)):
        if slot_list[i] == True:
            open_slot.append(i + 1)
            
    
    

    return open_slot

def ending(player):
    if player== user_num:
        print("You Win")
        
    elif player== com_num:
        print("You Lost")
    elif checkslot()== []:
        print("Draw!!")
    else:
        print("Error")
    restart()
    
    
def restart():
    restart = input("Play Again?(y/n)\n")
    if restart == "y" or "yes" or "Yes":
        clearScreen()
        print("Restart")
        playGame()
    else:
        print("***Thanks for playing***")
        clearScreen()
        

    
    
    
def checkWin(player):
    if checkSlot() == []:
        print("No open Slot")
        #break
    for i in range(0,3):
        rows_win = (board[i, :] == player).all()   
        cols_win = (board[:, i] == player).all()
        
        if rows_win or cols_win:
            ending(player)
        diag1_win = (np.diag(board) == player).all()
        diag2_win = (np.diag(np.fliplr(board)) == player).all()
    
        if diag1_win or diag2_win:
            ending(player)
        
    return nextTurn(player)

def nextTurn(player):
    if player == com_num:
        userTurn()
    if player == user_num:
        compTurn()
        
def place_letter(current_num,current_input):
    
    index = np.where(array == current_input)
    board[index] = current_num

            
def userTurn():
    displayBoard()
    
    user_input =int(input("Pick an open slot: "))
    #user_input = int(user_input)
    
    if user_input in checkSlot():
        place_letter(user_num, user_input)
    else:
        print("That's not a open slots.")
        userTurn()
        
    checkWin(user_num)

def compTurn():
# Randomly chooses from open_slot to place its letter 
    #displayBoard()
    open_slot = checkSlot()
    comp_input = random.choice(open_slot)
    place_letter(com_num, comp_input)
    checkWin(com_num)
    
#main function
playGame()
# Out:
# Its your turn will go with X
#
#
#            |   |
#         ---+---+---
#            |   |
#         ---+---+---
#            |   |
#
#
# Pick an open slot: 5
#
#
#          O |   |
#         ---+---+---
#            | X |
#         ---+---+---
#            |   |
#
#
# Pick an open slot: 2
#
#
#          O | X |
#         ---+---+---
#            | X |
#         ---+---+---
#          O |   |
#
#
# Pick an open slot: 8
# You Win
#
#
#          O | X |
#         ---+---+---
#            | X |
#         ---+---+---
#          O | X | O
#
#
# Pick an open slot: 4
# You Win
#
#
#          O | X |
#         ---+---+---
#          X | X | O
#         ---+---+---
#          O | X | O
#
#
# Pick an open slot: 3
# No open Slot
# You Win
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-d528d2024e27> in <module>
#     158
#     159 #main function
# --> 160 playGame()
# ...
